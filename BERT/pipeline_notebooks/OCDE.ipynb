# %%
import pandas as pd
import os 
from preprocess.translate import translate_OCDE_features

filePATH = os.path.join(path, "ocde_area_traduction.csv")
df_translations = pd.read_csv(filePATH)
trans = translate_OCDE_features(df, "Categoria Disciplina", df_translations)

filePATH = os.path.join(path, "ocde_subarea_traduction.csv")
df_translations = pd.read_csv(filePATH)
trans = translate_OCDE_features(df, "Sub Area Disciplina", df_translations)
